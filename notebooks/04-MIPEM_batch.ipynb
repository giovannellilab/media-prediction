# %% [markdown]
# # **MIPEM:** Media Ingredient Prediction for Environmental Microorganisms

# %%
import pandas as pd
import os

# %% [markdown]
# ### **User input:** <br>
# <u> **Insert your data here, and run the notebook. A PDF report will be generated in your working directory.** </u> <br>
# * A PDF report will be generated in your current working directory (**DATA_DIR**). <br>
# * **TEST_FILE** should be your organism's .csv file, with two columns: ["filename", "ec"]. These can be extracted from a .gff file in the 01-Data.ipynb notebook ("MAG Processing" section), or prepared independently. <br>
# * **OOI** is an optional filter for cases where your TEST_FILE has multiple organisms in the "filename" column (comment this line out if not).

# %%
DATA_DIR = "~/Desktop/Projects/media-prediction/" # Replace with the path to your working directory 
TEST_FILE = pd.read_csv(os.path.join(DATA_DIR, "data", "test.csv")) # Replace "test.csv" with your file

# %% [markdown]
# ### Initialization

# %% [markdown]
# Note: some notebooks were generated outside of this workflow by merging outputs from 01-Data.ipynb (e.g., UMAP_input.csv, test.csv, and ec-cofactor.csv)

# %%
# Setting random environment
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
RANDOM_SEED = 26

# For collecting report figures
from matplotlib.backends.backend_pdf import PdfPages
facet_figs = []

# Upload training dataset (derived from 01-Data.ipynb)
df = pd.read_csv(os.path.join(DATA_DIR, "data", "UMAP_input.csv"), low_memory=False)

# %% [markdown]
# #### Load Cache

# %%
import joblib
import numpy as np
import pickle

CACHE_DIR = "model_cache"

# Load cached files (derived from 02-Model_Cache.ipynb)
umap_model = joblib.load(f"{CACHE_DIR}/umap_model.joblib")
umap_embedding = np.load(f"{CACHE_DIR}/umap_embedding.npy")
nn_model = joblib.load(f"{CACHE_DIR}/nn_model.joblib")
lof_model = joblib.load(f"{CACHE_DIR}/lof_model.joblib")
train_knn_mean_dist = np.load(f"{CACHE_DIR}/train_knn_mean_dist.npy")
train_lof_scores = np.load(f"{CACHE_DIR}/train_lof_scores.npy")
cluster_labels = np.load(f"{CACHE_DIR}/cluster_labels.npy")

with open(f"{CACHE_DIR}/train_metadata.pkl", "rb") as f:
    meta = pickle.load(f)

# %% [markdown]
# #### Format input

# %%
# Prepare batch query matrix:
batch_df = TEST_FILE.copy()

batch_df["filename"] = batch_df["filename"].astype(str)
batch_df["ec"] = batch_df["ec"].astype(str)

# Count EC occurrences per "filename" (test organism)
batch_counts = (
    batch_df
    .groupby(["filename", "ec"])
    .size()
    .reset_index(name="count")
)

# Pivot into feature matrix
batch_matrix = (
    batch_counts
    .pivot(index="filename", columns="ec", values="count")
    .fillna(0.0)
)

# Align batch query features to training features
train_features = df.drop(columns=["taxon_ids", "media_id"], errors="ignore")
batch_matrix = batch_matrix.reindex(columns=train_features.columns, fill_value=0)
batch_matrix = batch_matrix.astype(float)

print(f"Unique query taxa: {len(batch_matrix)}")
print("Batch matrix shape:", batch_matrix.shape)
# Out:
# Unique query taxa: 247
# Batch matrix shape: (247, 3635)

# %%
# Embed/project using cached model:
batch_embedding = umap_model.transform(batch_matrix)

embedding_df = pd.DataFrame({
    "filename": batch_matrix.index,
    "UMAP_16": batch_embedding[:, 15],
    "UMAP_2": batch_embedding[:, 1]
})

print(embedding_df.head())

# Build reference dataframe
reference_df = pd.DataFrame({
    "UMAP_16": umap_embedding[:, 15],
    "UMAP_2": umap_embedding[:, 1],
    "cluster": cluster_labels.astype(str)
})
# Out:
#                                             filename   UMAP_16    UMAP_2
# 0  KBase_derived_Bin.001.fastaBA_F_extracted_bins...  4.429256  4.116438
# 1  KBase_derived_Bin.001.fastaBA_S_extracted_bins...  3.185307  4.558076
# 2  KBase_derived_Bin.001.fastaCF_F_extracted_bins...  3.190970  4.564579
# 3  KBase_derived_Bin.001.fastaCG_S_extracted_bins...  3.646628  4.442335
# 4  KBase_derived_Bin.001.fastaFE_F_extracted_bins...  3.189345  4.543664

# %%
import plotly.graph_objects as go
palette = [
    "#1f77b4", "#aec7e8",
    "#ff7f0e", "#ffbb78",
    "#2ca02c", "#98df8a",
    "#d62728", "#ff9896",
    "#9467bd", "#c5b0d5",
    "#8c564b", "#c49c94",
    "#e377c2", "#f7b6d2",
    "#7f7f7f", "#c7c7c7",
    "#bcbd22", "#dbdb8d",
    "#17becf", "#9edae5"
]

fig = go.Figure()

# Plot training dataset
fig.add_trace(
    go.Scattergl(
        x=reference_df["UMAP_16"],
        y=reference_df["UMAP_2"],
        mode="markers",
        name="Reference Organisms",
        marker=dict(
            size=5,
            color=cluster_labels,
            colorscale=palette,
            opacity=0.35
        ),
        hoverinfo="skip"
    )
)

# Plot test organisms
fig.add_trace(
    go.Scattergl(
        x=embedding_df["UMAP_16"],
        y=embedding_df["UMAP_2"],
        mode="markers",
        name="Query Taxa",
        
        # filename stored as hover metadata
        customdata=np.stack(
            [embedding_df["filename"]],
            axis=-1
        ),

        marker=dict(
            size=8,
            color="black",
            #symbol="diamond",
            line=dict(width=0)
        ),

        hovertemplate=(
            "<b>Filename:</b> %{customdata[0]}<br>"
            "UMAP_1: %{x:.3f}<br>"
            "UMAP_2: %{y:.3f}<extra></extra>"
        )
    )
)

fig.update_layout(
    title="Batch UMAP Projection",
    xaxis_title="UMAP 16",
    yaxis_title="UMAP 2",
    template="plotly_white",
    width=1100,
    height=800,
    hovermode="closest",
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="right",
        x=1
    )
)

fig.show()
# fig.write_html("batch_umap_projection.html")

# %%
#TODO: update code below this box to be batch-able

# %% [markdown]
# ### Nearest neighbors

# %%
test = reference_df.copy()

# Nearest neighbor model
distances, indices = nn_model.kneighbors(test)
test_mean_dist = distances[:, 1:].mean()

# Global distance
knn_percentile = (train_knn_mean_dist < test_mean_dist).mean() * 100

# Local outlier factor
lof_score = -lof_model.score_samples(test)[0]
lof_percentile = (train_lof_scores < lof_score).mean() * 100

print(f"kNN percentile: {knn_percentile:.1f}%")
print(f"LOF percentile: {lof_percentile:.1f}%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       1 test = reference_df.copy()
#       3 # Nearest neighbor model
# ----> 4 distances, indices = nn_model.kneighbors(test)
#       5 test_mean_dist = distances[:, 1:].mean()
#       7 # Global distance
#
# File c:\Users\jakel\anaconda3\envs\media\Lib\site-packages\sklearn\neighbors\_base.py:838, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     836         X = _check_precomputed(X)
#     837     else:
# --> 838         X = validate_data(
#     839             self,
#     840             X,
#     841             ensure_all_finite=ensure_all_finite,
#     842             accept_sparse="csr",
#     843             reset=False,
#     844             order="C",
#     845         )
#     847 n_samples_fit = self.n_samples_fit_
#     848 if n_neighbors > n_samples_fit:
#
# File c:\Users\jakel\anaconda3\envs\media\Lib\site-packages\sklearn\utils\validation.py:2929, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2845 def validate_data(
#    2846     _estimator,
#    2847     /,
#    (...)   2853     **check_params,
#    2854 ):
#    2855     """Validate input data and set or check feature names and counts of the input.
#    2856
#    2857     This helper function should be used in an estimator that requires input
#    (...)   2927         validated.
#    2928     """
# -> 2929     _check_feature_names(_estimator, X, reset=reset)
#    2930     tags = get_tags(_estimator)
#    2931     if y is None and tags.target_tags.required:
#
# File c:\Users\jakel\anaconda3\envs\media\Lib\site-packages\sklearn\utils\validation.py:2787, in _check_feature_names(estimator, X, reset)
#    2784 if not missing_names and not unexpected_names:
#    2785     message += "Feature names must be in the same order as they were in fit.\n"
# -> 2787 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - UMAP_16
# - UMAP_2
# - cluster
# Feature names seen at fit time, yet now missing:
# - 1.1.1.1
# - 1.1.1.100
# - 1.1.1.101
# - 1.1.1.102
# - 1.1.1.103
# - ...

# %%
# Show nearest neighbors and Jaccard distances
neighbor_indices = np.array(indices, dtype=int).flatten()
neighbor_distances = distances.flatten()
neighbors = df.iloc[neighbor_indices][['taxon_id', 'media_id']].copy()
neighbors['jaccard_distance'] = neighbor_distances

print("Nearest neighbors:")
display(neighbors)
# Out:
# Nearest neighbors:
#        taxon_id media_id  jaccard_distance
# 6419    47834.0    1076b          0.803419
# 362   1136073.0    1076b          0.814159
# 6420    47835.0    1076b          0.817460
# 5422   358687.0     J346          0.840764
# 5357   351343.0     J346          0.840764
# 6045   424799.0     J346          0.840764
# 646    126734.0    1012a          0.841530
# 1797     1597.0      J84          0.845588
# 7347   650366.0      J13          0.845588
# 1400     1490.0      J84          0.845588
# 7349   650367.0      J13          0.845588
# 7350   650367.0      J84          0.845588
# 1399     1490.0      J13          0.845588
# 7348   650366.0      J84          0.845588
# 1776     1589.0      J13          0.847561
# 1838     1610.0      J84          0.847561

# %% [markdown]
# #### Nearest neighbor media

# %%
neighbors_df = pd.DataFrame(neighbors)
neighbors_df = neighbors_df.drop(columns=["jaccard_distance"])

# Show the media of the nearest neighboring taxa based on their metabolic characteristics
media_df = pd.read_csv(os.path.join(DATA_DIR, "data", "mediadive", "mediadive-complete.csv"), low_memory=False) #"mediadive-complete-explo.csv"
prediction = pd.merge(left=neighbors_df, right=media_df, on="media_id", how="left")
prediction = prediction.drop(["taxon_id"], axis=1)

# Occurrence column shows how many of the neighbors utilize each media type
prediction["occurrence"] = prediction["media_id"].map(prediction["media_id"].value_counts(normalize=True))
prediction = prediction.drop_duplicates()

# Sort by occurrence
df_sorted = prediction.sort_values(by="occurrence", ascending=False)

df_sorted.head()
# Out:
#   media_id           solutions                                 solution_names  \
# 7      J84              [3711]                              ['Main sol. J84']
# 8      J13  [3632, 3633, 3634]  ['Main sol. J13', 'Solution A', 'Solution B']
# 0    1076b              [2173]                            ['Main sol. 1076b']
# 3     J346              [4066]                             ['Main sol. J346']
# 6    1012a              [6336]                            ['Main sol. 1012a']
#
#                                           components  \
# 7           ['GAM broth', 'Agar', 'Distilled water']
# 8  ['Lab-Lemco beef extract', 'Proteose peptone n...
# 0  ['PPLO broth', 'Tryptone', 'Bacto peptone', 'D...
# 3  ['Yeast extract', 'Proteose peptone no. 3', 'C...
# 6  ['Nutrient broth', 'Casamino acids', 'Yeast ex...
#
#                                        component_ids  \
# 7                                       [1620, 3, 4]
# 8  [599, 316, 124, 125, 16, 1600, 5, 199, 22, 3, ...
# 0  [953, 71, 19, 4, 958, 1680, 16, 954, 960, 5, 3...
# 3           [16, 316, 101, 5, 199, 438, 10, 8, 3, 4]
# 6                        [269, 101, 16, 3, 79, 7, 4]
#
#                                         component_gL  \
# 7                                      [59, 2, None]
# 8  [2.85714, 9.52381, 4.7619, 2.85714, 4.7619, No...
# 0  [3.5, 10, 5, None, 0.2, None, 0.4, None, None,...
# 3  [0.5, 0.5, 0.5, 0.5, 0.5, 0.3, 0.3, 0.05, 15, ...
# 6                [0.8, 0.5, 0.1, 12, 0.6, 0.3, None]
#
#                                                steps  \
# 7                                             [None]
# 8  [[{'step': 'Adjust pH to 7.2.'}, {'step': 'To ...
# 0  [[{'step': 'The difference between this medium...
# 3  [[{'step': 'Adjust pH to 7.2.'}, {'step': 'Com...
# 6  [[{'step': 'Preparation of double-layered agar...
#
#                   sub_solutions  solution_ids solution_ml  occurrence
# 7                            []            []          []      0.3125
# 8  ['Solution A', 'Solution B']  [3633, 3634]     [10, 5]      0.2500
# 0                            []            []          []      0.1875
# 3                            []            []          []      0.1875
# 6                            []            []          []      0.0625

# %%
# Gather list of nearest neighbors
neighbor_ids = neighbors["taxon_id"].to_list()

# %% [markdown]
# #### Cofactor comparison

# %%
# Load training set EC and cofactor info
training_cofactors = pd.read_csv(os.path.join(DATA_DIR, "data", "ec-cofactor.csv"))

# Filter for the nearest neighbors (rather than entire training dataset)
neighbors_list = neighbors["taxon_id"].to_list()
filt = training_cofactors["taxon_id"].isin(neighbors_list)
train_co = training_cofactors[filt]

train_co.head()
# Out:
#        media_id  taxon_id   source         ec CofactorFinal
# 100676    1012a  126734.0  uniprot   3.6.1.66            Mg
# 100677    1012a  126734.0  uniprot  2.1.1.192            Fe
# 100678    1012a  126734.0  uniprot    2.7.4.3            Mg
# 100679    1012a  126734.0  uniprot   3.1.26.3            Mg
# 100680    1012a  126734.0  uniprot  4.2.1.113         metal

# %%
# Align test case cofactor info based on EC numbers
test_co = bin[["filename", "ec"]]
tr_co = pd.read_csv(os.path.join(DATA_DIR, "data", "cofactors", "cofactors-taxa.csv"), low_memory=False)
tr_co = tr_co[["Query EC", "CofactorFinal"]]
tr_co = tr_co.rename(columns={"Query EC":"ec"})
merge_co = pd.merge(left=test_co, right=tr_co, on="ec", how="left")

# Focus on metals / trace elements
metals = pd.read_csv(os.path.join(DATA_DIR, "data", "cofactors", "metals-list.csv"))
metals_list = metals["Metals"].to_list()
filter = merge_co["CofactorFinal"].isin(metals_list)
test_co = merge_co[filter]

test_co.head()
# Out:
#                                             filename        ec CofactorFinal
# 0  KBase_derived_Bin.003.fastaCG_F_extracted_bins...  3.6.4.12            Fe
# 2  KBase_derived_Bin.003.fastaCG_F_extracted_bins...  3.6.4.12            Mg
# 3  KBase_derived_Bin.003.fastaCG_F_extracted_bins...  3.6.4.12         metal
# 4  KBase_derived_Bin.003.fastaCG_F_extracted_bins...  3.6.4.12            Zn
# 5  KBase_derived_Bin.003.fastaCG_F_extracted_bins...  3.6.4.12            Mn

# %%
# Dictionary for undefined metals
dictionary = {"a monovalent": "UM", "metal": "UM"}

# Calculating relative abundances of cofactors between training vs. test case
def summarize_cofactors(df, label):
    return (
        df.assign(
            CofactorFinal=df["CofactorFinal"].replace(dictionary, regex=True)
        )
        .value_counts("CofactorFinal", normalize=True)
        .rename("ra")
        .reset_index()
        .assign(
            ct=lambda x: (x["ra"] * len(df)).round().astype(int),
            Set=label
        )
        [["CofactorFinal", "ct", "ra", "Set"]]
    )

# Storing dataframe for our relative abundances
counts = pd.concat([summarize_cofactors(train_co, "Training"), summarize_cofactors(test_co, "Test")], ignore_index=True)
counts = counts.sort_values("ct", ascending=False)

# %%
import seaborn as sns
sns.set_theme(style="white")

colors = ["#f5c767", "#ee9b00"]

g = sns.catplot(
    data=counts, kind="bar",
    x="CofactorFinal", y="ra", hue="Set", 
    palette=colors, alpha=1, height=6, aspect=8.5/6
)

g.despine(left=True)
g.set_axis_labels("", "Relative Cofactor Abundance")
g.tick_params(axis='x', rotation=30)
g.fig.suptitle("Test-organisms's cofactor usage relative to nearest neighbors", y=0.98, fontsize=12)
g.legend.set_loc("upper right")
g.legend.set_title("")
g.fig.set_size_inches(8.5, 6)

# %% [markdown]
# #### EC Comparison

# %%
# Convert taxa2ec info to list
taxa2ec_df = pd.read_csv(os.path.join(DATA_DIR, "data", "taxa2ec-final.csv"), low_memory=False)
neighbor_filter = taxa2ec_df["taxon_id"].isin(neighbor_ids)
neighbor_ec = taxa2ec_df[neighbor_filter]
taxa2ec_list = neighbor_ec['ec'].to_list()

# Convert test info to list
test_list = test_df["ec"].to_list()

# %%
print(len(set(taxa2ec_list)), "unique EC numbers in the training dataset.")
print(len(set(test_list)), "unique EC numbers in the test organism.")
# Out:
# 456 unique EC numbers in the training dataset.
# 1823 unique EC numbers in the test organism.

# %%
from matplotlib import pyplot as plt
from matplotlib_venn import venn2

fig, ax = plt.subplots(figsize=(8.5,6))
v = venn2(
    subsets=[set(taxa2ec_list), set(test_list)],
    set_labels=["Training Dataset (neighbors)", "Test Organism"],
    set_colors=["lime", "orange"]
)
ax.axis('off')
fig.suptitle("Overlap between unique EC numbers", fontsize=14, y=0.90)

facet_figs.append(fig)

# %% [markdown]
# #### Neighbor taxonomy

# %%
from ete3 import NCBITaxa, TreeStyle, NodeStyle
import matplotlib.pyplot as plt
from PIL import Image

# Build and annotate a circular tree
ncbi = NCBITaxa()
tree = ncbi.get_topology(neighbor_ids)

# Annotate with "Genus|species (taxon_id)""
for leaf in tree:
    taxid = int(leaf.name)
    name = ncbi.get_taxid_translator([taxid])[taxid]
    leaf.name = f"{name.replace(' ', '_')} ({taxid})"  # include taxid

# Format tree layout
nstyle = NodeStyle()
nstyle["size"] = 0
for n in tree.traverse():
    n.set_style(nstyle)

ts = TreeStyle()
ts.mode = "c"  # circular tree
ts.show_leaf_name = False
ts.show_branch_length = False
ts.show_branch_support = False
ts.scale = 20  # adjust spacing

# ETE3 only renders to files, save a temporary .png
png_file = "neighbor_tree.png"
tree.render(png_file, w=850, units="px", tree_style=ts)

# Load temporary .png into a Matplotlib figure
img = Image.open(png_file)
fig, ax = plt.subplots(figsize=(8.5, 8.5))
ax.imshow(img)
ax.axis("off")

facet_figs.append(fig)

# %% [markdown]
# ### Generate report

# %%
import sys
sys.path.append("..")
import modules.media_report as report
import matplotlib.image as mpimg
from PIL import Image

facet_figs.extend(
    report.generate_facet_figs(
        neighbors=neighbors,
        knn_percentile=knn_percentile,
        lof_percentile=lof_percentile,
        df_sorted=df_sorted,
        prediction=prediction
    )
)

facet_figs.append(g.fig)

report.cofactor_enrichment_barh(facet_figs, counts)

with PdfPages("report.pdf") as pdf:
    for fig_item in facet_figs:
        pdf.savefig(fig_item) 
        plt.close(fig_item)
